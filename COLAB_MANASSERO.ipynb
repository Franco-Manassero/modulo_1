# %% [markdown]
# <a href="https://colab.research.google.com/github/Franco-Manassero/modulo_1/blob/main/COLAB_MANASSERO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Te damos la bienvenida a Colab

# %% [markdown]
# # Este es mi primer cuaderno
#
# Aquí voy a mezclar código markdown con operaciones matemáticas
#
# *   sumar
# *   restar
# *   dividir
# *   multiplicar

# %%
a=1:100
b=a^2
plot(a, b, main = "presión del gas crítico", xlab = "volumen", ylab = "presión", type = "l", col = "blue")
# Out:
# Plot with title “presión del gas crítico”

# %%
a=3
b=5
a+b
# Out:
# [1] 8
